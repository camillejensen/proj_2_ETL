# %%
import pandas as pd
import json
import requests
from pprint import pprint

# %%
pd.options.display.max_colwidth = 200
past_data_csv_df = pd.read_csv("Resources/Food_Inspections_past.csv")
past_data_csv_df.head()
# Out:
#    Inspection ID                      DBA Name                      AKA Name  \
# 0          67757  DUNKIN DONUTS/BASKIN-ROBBINS  DUNKIN DONUTS/BASKIN-ROBBINS
# 1          52234                      Cafe 608                      Cafe 608
# 2          70269                   mr.daniel's                   mr.daniel's
# 3          67733                     WOLCOTT'S                       TROQUET
# 4         104236                    TEMPO CAFE                    TEMPO CAFE
#
#    License # Facility Type             Risk              Address     City  \
# 0  1380279.0    Restaurant  Risk 2 (Medium)    100 W RANDOLPH ST  CHICAGO
# 1  2013328.0    Restaurant    Risk 1 (High)      608 W BARRY AVE  CHICAGO
# 2  1899292.0    Restaurant    Risk 1 (High)   5645 W BELMONT AVE  CHICAGO
# 3  1992040.0    Restaurant    Risk 1 (High)  1834 W MONTROSE AVE  CHICAGO
# 4    80916.0    Restaurant    Risk 1 (High)      6 E CHESTNUT ST  CHICAGO
#
#   State      Zip Inspection Date        Inspection Type Results  \
# 0    IL  60601.0      01/04/2010            Tag Removal    Pass
# 1    IL  60657.0      01/04/2010  License Re-Inspection    Pass
# 2    IL  60634.0      01/04/2010  License Re-Inspection    Pass
# 3    IL  60613.0      01/04/2010  License Re-Inspection    Pass
# 4    IL  60611.0      01/04/2010                Canvass    Fail
#
#                                                                                                                                                                                                 Violations  \
# 0                                                                                                                                                                                                      NaN
# 1                                                                                                                                                                                                      NaN
# 2                                                                                                                                                                                                      NaN
# 3                                                                                                                                                                                                      NaN
# 4  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS PROTECTED/RODENT PROOFED, A WRITTEN LOG SHALL BE MAINTAINED AVAILABLE TO THE INSPECTORS - Comments: All necessary control measures shall be used ...
#
#     Latitude  Longitude                                  Location
# 0  41.884586 -87.631010   (41.88458626715456, -87.63101044588599)
# 1  41.938007 -87.644755   (41.938006880423615, -87.6447545707008)
# 2  41.938443 -87.768318   (41.93844282365204, -87.76831838068422)
# 3  41.961606 -87.675967  (41.961605669949854, -87.67596676683779)
# 4  41.898431 -87.628009    (41.89843137207629, -87.6280091630558)

# %%
past_data_csv_df= past_data_csv_df.drop(columns=['Latitude', 'Longitude', 'Location'])
past_data_csv_df.head()
# Out:
#    Inspection ID                      DBA Name                      AKA Name  \
# 0          67757  DUNKIN DONUTS/BASKIN-ROBBINS  DUNKIN DONUTS/BASKIN-ROBBINS
# 1          52234                      Cafe 608                      Cafe 608
# 2          70269                   mr.daniel's                   mr.daniel's
# 3          67733                     WOLCOTT'S                       TROQUET
# 4         104236                    TEMPO CAFE                    TEMPO CAFE
#
#    License # Facility Type             Risk              Address     City  \
# 0  1380279.0    Restaurant  Risk 2 (Medium)    100 W RANDOLPH ST  CHICAGO
# 1  2013328.0    Restaurant    Risk 1 (High)      608 W BARRY AVE  CHICAGO
# 2  1899292.0    Restaurant    Risk 1 (High)   5645 W BELMONT AVE  CHICAGO
# 3  1992040.0    Restaurant    Risk 1 (High)  1834 W MONTROSE AVE  CHICAGO
# 4    80916.0    Restaurant    Risk 1 (High)      6 E CHESTNUT ST  CHICAGO
#
#   State      Zip Inspection Date        Inspection Type Results  \
# 0    IL  60601.0      01/04/2010            Tag Removal    Pass
# 1    IL  60657.0      01/04/2010  License Re-Inspection    Pass
# 2    IL  60634.0      01/04/2010  License Re-Inspection    Pass
# 3    IL  60613.0      01/04/2010  License Re-Inspection    Pass
# 4    IL  60611.0      01/04/2010                Canvass    Fail
#
#                                                                                                                                                                                                 Violations
# 0                                                                                                                                                                                                      NaN
# 1                                                                                                                                                                                                      NaN
# 2                                                                                                                                                                                                      NaN
# 3                                                                                                                                                                                                      NaN
# 4  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS PROTECTED/RODENT PROOFED, A WRITTEN LOG SHALL BE MAINTAINED AVAILABLE TO THE INSPECTORS - Comments: All necessary control measures shall be used ...

# %%
columns = list(past_data_csv_df)
columns
# Out:
# ['Inspection ID',
#  'DBA Name',
#  'AKA Name',
#  'License #',
#  'Facility Type',
#  'Risk',
#  'Address',
#  'City',
#  'State',
#  'Zip',
#  'Inspection Date',
#  'Inspection Type',
#  'Results',
#  'Violations']

# %%
#set url for API
url= "https://data.cityofchicago.org/resource/qizy-d2wf.json"

current_data_response= requests.get(url)
current_data_json = current_data_response.json()

# %%
pprint(current_data_json)
# Out:
# [{':@computed_region_43wa_7qmu': '11',
#   ':@computed_region_6mkv_f3dw': '22620',
#   ':@computed_region_awaf_s7ux': '16',
#   ':@computed_region_bdys_3d7i': '109',
#   ':@computed_region_vrxf_vc4k': '25',
#   'address': '1731-1735 N ELSTON AVE ',
#   'aka_name': 'CREATIVE SCHOLARS PRESCHOOL',
#   'city': 'CHICAGO',
#   'dba_name': 'CREATIVE SCHOLARS PRESCHOOL',
#   'facility_type': "Children's Services Facility",
#   'inspection_date': '2023-01-17T00:00:00.000',
#   'inspection_id': '2569739',
#   'inspection_type': 'License',
#   'latitude': '41.9139251579717',
#   'license_': '2216013',
#   'location': {'latitude': '41.9139251579717',
#                'longitude': '-87.66436839626788',
#                'needs_recoding': False},
#   'longitude': '-87.66436839626788',
#   'results': 'Pass',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & '
#                 'CLEANED - Comments: OBSERVED ONE UNISEX STAFF RESTROOM '
#                 'MISSING A COVERED TRASH RECEPTACLE. INSTRUCTED TO PROVIDE.',
#   'zip': '60622'},
#  {':@computed_region_43wa_7qmu': '18',
#   ':@computed_region_6mkv_f3dw': '21849',
#   ':@computed_region_awaf_s7ux': '13',
#   ':@computed_region_bdys_3d7i': '665',
#   ':@computed_region_vrxf_vc4k': '6',
#   'address': '2324 W GIDDINGS ST ',
#   'aka_name': 'PACIUGO CHICAGO',
#   'city': 'CHICAGO',
#   'dba_name': 'PACIUGO CHICAGO',
#   'facility_type': 'Mobile Food Dispenser',
#   'inspection_date': '2023-01-17T00:00:00.000',
#   'inspection_id': '2569731',
#   'inspection_type': 'Canvass',
#   'latitude': '41.96765092713031',
#   'license_': '2240574',
#   'location': {'latitude': '41.96765092713031',
#                'longitude': '-87.6875610952487',
#                'needs_recoding': False},
#   'longitude': '-87.6875610952487',
#   'results': 'Out of Business',
#   'risk': 'Risk 3 (Low)',
#   'state': 'IL',
#   'zip': '60625'},
#  {':@computed_region_6mkv_f3dw': '16197',
#   ':@computed_region_bdys_3d7i': '170',
#   'address': '11601 W TOUHY AVE ',
#   'aka_name': 'LA TAPENADE  (T1-B5)',
#   'city': 'CHICAGO',
#   'dba_name': 'HOST INTERNATIONAL B05',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569725',
#   'inspection_type': 'Canvass Re-Inspection',
#   'latitude': '42.008536400868735',
#   'license_': '34203',
#   'location': {'latitude': '42.008536400868735',
#                'longitude': '-87.91442843927047',
#                'needs_recoding': False},
#   'longitude': '-87.91442843927047',
#   'results': 'Pass',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'zip': '60666'},
#  {':@computed_region_43wa_7qmu': '20',
#   ':@computed_region_6mkv_f3dw': '21849',
#   ':@computed_region_awaf_s7ux': '2',
#   ':@computed_region_bdys_3d7i': '118',
#   ':@computed_region_vrxf_vc4k': '14',
#   'address': '4700 N KIMBALL AVE ',
#   'aka_name': 'TAO THONG',
#   'city': 'CHICAGO',
#   'dba_name': 'TAO THONG',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569640',
#   'inspection_type': 'Canvass',
#   'latitude': '41.96667122670007',
#   'license_': '2595274',
#   'location': {'latitude': '41.96667122670007',
#                'longitude': '-87.71345814571208',
#                'needs_recoding': False},
#   'longitude': '-87.71345814571208',
#   'results': 'Out of Business',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'zip': '60625'},
#  {':@computed_region_43wa_7qmu': '42',
#   ':@computed_region_6mkv_f3dw': '4447',
#   ':@computed_region_awaf_s7ux': '33',
#   ':@computed_region_bdys_3d7i': '256',
#   ':@computed_region_vrxf_vc4k': '73',
#   'address': '3128 W 103RD ST ',
#   'aka_name': 'JEWEL FOOD STORE #3114',
#   'city': 'CHICAGO',
#   'dba_name': 'JEWEL FOOD STORE #3114',
#   'facility_type': 'Grocery Store',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569664',
#   'inspection_type': 'Canvass',
#   'latitude': '41.70631284461492',
#   'license_': '1388',
#   'location': {'latitude': '41.70631284461492',
#                'longitude': '-87.6997671192086',
#                'needs_recoding': False},
#   'longitude': '-87.6997671192086',
#   'results': 'Pass',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '45. SINGLE-USE/SINGLE-SERVICE ARTICLES: PROPERLY STORED & '
#                 'USED - Comments: OBSERVED SINGLE SERVICE ARTICLES STORED ON '
#                 'FLOOR IN MEAT WALK-IN COOLER. INSTRUCTED MANAGER TO ELEVATE '
#                 'ALL SINGLE SERVICE ARTICLES OFF FLOOR. | 47. FOOD & NON-FOOD '
#                 'CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & '
#                 'USED - Comments: OBSERVED MILK CRATES USED AS SHELVING UNITS '
#                 'IN STORAGE AREAS. INSTRUCTED MANAGER TO PROVIDE ADEQUATE '
#                 'SHELVING FOR EASY CLEANING AND PEST CONTROL. | 49. '
#                 'NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: OBSERVED '
#                 'GREASE BUILDUP AND FOOD DEBRIS ON INTERIOR AND EXTERIOR '
#                 'SURFACES OF FRYERS, HOT HOLDING UNITS, PREP TABLES AND '
#                 'SHELVING UNITS IN PREP AREAS. INSTRUCTED MANAGER TO CLEAN AND '
#                 'MAINTAIN. | 51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - '
#                 'Comments: OBSERVED LEAKING DRAINPIPE UNDER HAND WASHING SINK '
#                 'IN SEAFOOD PREP AREA AND UNISEX WASHROOM IN REAR STORAGE '
#                 'AREA. INSTRUCTED MANAGER TO REPAIR AND MAINTAIN. | 55. '
#                 'PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: '
#                 'OBSERVED PEELING PAINT ON FLOOR IN DELI AND MEAT PREP AREAS. '
#                 'OBSERVED STAINED TILES IN BREAKROOM. INSTRUCTED MANAGER TO '
#                 'REPAIR/REPLACE AND MAINTAIN. | 55. PHYSICAL FACILITIES '
#                 'INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED LIGHT '
#                 'SHIELDS IN NEED OF CLEANING IN PREP AND WALK-IN COOLER AREAS '
#                 'OBSERVED FOOD DEBRIS AND DUST BUILDUP ON FLOORS UNDER HOT '
#                 'HOLDING UNIT IN DELI, ALONG WALLS AND CORNERS IN PREP AND '
#                 'STORAGE AREAS. INSTRUCTED MANAGER TO CLEAN AND MAINTAIN. | '
#                 '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - '
#                 'Comments: OBSERVED OVERHEAD WATER LINES NOT SHIELDED IN '
#                 'PRODUCE PREP AREA. INSTRUCTED MANAGER TO ENCASE WATER LINES '
#                 'TO PROTECT FROM POTENTIAL DRIPS OR OVERHEAD LEAKAGE.',
#   'zip': '60655'},
#  {':@computed_region_43wa_7qmu': '21',
#   ':@computed_region_6mkv_f3dw': '21538',
#   ':@computed_region_awaf_s7ux': '15',
#   ':@computed_region_bdys_3d7i': '138',
#   ':@computed_region_vrxf_vc4k': '22',
#   'address': '3650 W BELMONT AVE ',
#   'aka_name': "GORDITAS LOLI'S #2",
#   'city': 'CHICAGO',
#   'dba_name': "GORDITAS LOLI'S #2",
#   'facility_type': 'Restaurant',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569714',
#   'inspection_type': 'Canvass',
#   'latitude': '41.93930172570259',
#   'license_': '2583373',
#   'location': {'latitude': '41.93930172570259',
#                'longitude': '-87.71938935474189',
#                'needs_recoding': False},
#   'longitude': '-87.71938935474189',
#   'results': 'Fail',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '36. THERMOMETERS PROVIDED & ACCURATE - Comments: INSTRUCTED '
#                 'TO PROVIDE THERMOMETER VISIBLE INSIDE ALL COOLERS. | 47. FOOD '
#                 '& NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, '
#                 'CONSTRUCTED & USED - Comments: INSTRUCTED TO CLEAN AND '
#                 'REPAINT EXTERIOR TOP OF GREASE BOX WITH RUST ACCUMULATION '
#                 'UNDERNEATH 3 COMPARTMENT SINK IN REAR PREP/DISHWASHING AREA. '
#                 '| 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY '
#                 'DESIGNED, CONSTRUCTED & USED - Comments: INSTRUCTED TO '
#                 'TRANSFER FOOD PRODUCTS FROM AN OPEN ORIGINAL CAN (EVAPORATED '
#                 'MILK) CONTAINER INTO FOOD GRADE CONTAINER FOR PROPER FOOD '
#                 'STORAGE INSIDE THE COOLER. | 60. PREVIOUS CORE VIOLATION '
#                 'CORRECTED - Comments: PREVIOUS CORE VIOLATIONS NOT CORRECTED '
#                 'FROM INSPECTION REPORT# 2545590 ISSUED ON 12-14-2021 PRIORITY '
#                 'FOUNDATION VIOLATION 7-42-090    CITATION ISSUED  #55 - '
#                 'REPLACE THE BROKEN AND MISSING FLOOR TILES IN THE REAR FOOD '
#                 'PREP AREA. #57 - NO PROOF OF FOOD HANDLER TRAINING OR '
#                 'CERTIFICATE ON SITE FOR EMPLOYEE ON SITE. MUST PROVIDE FOR '
#                 'ALL REQUIRED EMPLOYEES',
#   'zip': '60618'},
#  {':@computed_region_43wa_7qmu': '11',
#   ':@computed_region_6mkv_f3dw': '21560',
#   ':@computed_region_awaf_s7ux': '16',
#   ':@computed_region_bdys_3d7i': '438',
#   ':@computed_region_vrxf_vc4k': '25',
#   'address': '1916 W NORTH AVE ',
#   'aka_name': 'COOKING FOOLS LLC',
#   'city': 'CHICAGO',
#   'dba_name': 'COOKING FOOLS LLC',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569694',
#   'inspection_type': 'Non-Inspection',
#   'latitude': '41.910622805831906',
#   'license_': '1355251',
#   'location': {'latitude': '41.910622805831906',
#                'longitude': '-87.67576194185494',
#                'needs_recoding': False},
#   'longitude': '-87.67576194185494',
#   'results': 'No Entry',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'zip': '60622'},
#  {':@computed_region_43wa_7qmu': '6',
#   ':@computed_region_6mkv_f3dw': '21867',
#   ':@computed_region_awaf_s7ux': '23',
#   ':@computed_region_bdys_3d7i': '292',
#   ':@computed_region_vrxf_vc4k': '63',
#   'address': '6018 S KARLOV AVE ',
#   'aka_name': 'RICHARDSON MIDDLE SCHOOL',
#   'city': 'CHICAGO',
#   'dba_name': 'RICHARDSON MIDDLE SCHOOL',
#   'facility_type': 'School',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569666',
#   'inspection_type': 'Canvass',
#   'latitude': '41.783484783129275',
#   'license_': '3619531',
#   'location': {'latitude': '41.783484783129275',
#                'longitude': '-87.72548610626416',
#                'needs_recoding': False},
#   'longitude': '-87.72548610626416',
#   'results': 'Pass',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'zip': '60629'},
#  {':@computed_region_43wa_7qmu': '27',
#   ':@computed_region_6mkv_f3dw': '22528',
#   ':@computed_region_awaf_s7ux': '42',
#   ':@computed_region_bdys_3d7i': '320',
#   ':@computed_region_vrxf_vc4k': '20',
#   'address': '6700 N DAMEN AVE ',
#   'aka_name': 'WARREN PARK HEALTH & LIVING CENTER',
#   'city': 'CHICAGO',
#   'dba_name': 'WARREN PARK HEALTH & LIVING CENTER, LLC',
#   'facility_type': 'Long Term Care',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569673',
#   'inspection_type': 'Canvass',
#   'latitude': '42.0033892278461',
#   'license_': '2208054',
#   'location': {'latitude': '42.0033892278461',
#                'longitude': '-87.68046070936003',
#                'needs_recoding': False},
#   'longitude': '-87.68046070936003',
#   'results': 'Pass',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: '
#                 'OBSERVED LEAKING CONDITION AT SPRAYER SINK AT DISH MACHINE '
#                 'AND LEAKING CONDITION ON DISH MAHCINE. REPAIR LEAKS AND '
#                 'MAINTAIN. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & '
#                 'CLEAN - Comments: OBSERVED FLOOR AND FLOOR COVING IN '
#                 'DISREPAIR UNDER DISH MACHINE IN KITCHEN REPAIR FLOOR AND '
#                 'FLOOR COVING AND MAINTAIN. | 55. PHYSICAL FACILITIES '
#                 'INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED WATER ON '
#                 'FLOOR OF KITCHEN UNDER DISH MACHINE. REMOVE WATER AND '
#                 'MAINTAIN FLOOR IN A CLEAN AND DRY CONDITION.',
#   'zip': '60645'},
#  {':@computed_region_6mkv_f3dw': '16197',
#   ':@computed_region_bdys_3d7i': '170',
#   'address': '11601 W TOUHY AVE ',
#   'aka_name': 'WOLFGANG PUCK (T1 B7)',
#   'city': 'CHICAGO',
#   'dba_name': 'WOLFGANG PUCK, T1',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569677',
#   'inspection_type': 'Canvass',
#   'latitude': '42.008536400868735',
#   'license_': '34157',
#   'location': {'latitude': '42.008536400868735',
#                'longitude': '-87.91442843927047',
#                'needs_recoding': False},
#   'longitude': '-87.91442843927047',
#   'results': 'Pass',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '36. THERMOMETERS PROVIDED & ACCURATE - Comments: OBSERVED NO '
#                 'THERMOMETER INSIDE THE REAR 2-DOOR STAND-UP COOLER.INSTRUCTED '
#                 'TO PROVIDE AND MAINTAIN A VISIBLE AND ACCURATE WORKING '
#                 'THERMOMETER IN COOLER. | 49. NON-FOOD/FOOD CONTACT SURFACES '
#                 'CLEAN - Comments: INSTRUCTED TO DETAIL CLEAN INTERIORS OF '
#                 'REAR REFRIGERATION UNITS ACROSS FROM THE REAR '
#                 'PREP/DISHWASHING 3-COMPARTMENT SINK TO REMOVE FOOD PREP '
#                 'LIQUID SPILLAGE AND MAINTAIN. | 56. ADEQUATE VENTILATION & '
#                 'LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED MISSING '
#                 'LIGHT SHIELD FOR LIGHT FIXTURE LOCATED AT REAR '
#                 'PREP/DISHWASHING  AREA.INSTRUCTED TO PROVIDE MISSING LIGHT '
#                 'SHIELD AND MAINTAIN.',
#   'zip': '60666'},
#  {':@computed_region_43wa_7qmu': '41',
#   ':@computed_region_6mkv_f3dw': '21560',
#   ':@computed_region_awaf_s7ux': '24',
#   ':@computed_region_bdys_3d7i': '481',
#   ':@computed_region_vrxf_vc4k': '25',
#   'address': '1470 N MILWAUKEE AVE ',
#   'aka_name': 'THE BONGO ROOM',
#   'city': 'CHICAGO',
#   'dba_name': 'THE BONGO ROOM',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569657',
#   'inspection_type': 'Canvass',
#   'latitude': '41.908523906377425',
#   'license_': '33114',
#   'location': {'latitude': '41.908523906377425',
#                'longitude': '-87.67479749884576',
#                'needs_recoding': False},
#   'longitude': '-87.67479749884576',
#   'results': 'Pass',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND '
#                 'ACCESSIBLE - Comments: OBSERVED NO HANDWASHING SIGNAGE AT THE '
#                 'EXPOSED HANDWASHING SINK LOCATED IN THE BAR. INSTRUCTED TO '
#                 'PROVIDE. | 39. CONTAMINATION PREVENTED DURING FOOD '
#                 'PREPARATION, STORAGE & DISPLAY - Comments: OBSERVED OLD SOUR '
#                 'CREAM CONTAINERS BEING USED TO STORE DELI MEATS AND OTHER '
#                 'INGREDIENTS. INSTRUCTED TO USE ONLY REUSABLE, FOOD GRADE '
#                 'STORAGE CONTAINERS.',
#   'zip': '60622'},
#  {':@computed_region_43wa_7qmu': '41',
#   ':@computed_region_6mkv_f3dw': '22620',
#   ':@computed_region_awaf_s7ux': '41',
#   ':@computed_region_bdys_3d7i': '521',
#   ':@computed_region_vrxf_vc4k': '25',
#   'address': '636 N RACINE AVE ',
#   'aka_name': 'AMY BECK CAKE DESIGN, LLC',
#   'city': 'CHICAGO',
#   'dba_name': 'AMY BECK CAKE DESIGN, LLC',
#   'facility_type': 'Bakery',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569689',
#   'inspection_type': 'Canvass',
#   'latitude': '41.893380429024546',
#   'license_': '2079264',
#   'location': {'latitude': '41.893380429024546',
#                'longitude': '-87.65758773796799',
#                'needs_recoding': False},
#   'longitude': '-87.65758773796799',
#   'results': 'Out of Business',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'zip': '60642'},
#  {':@computed_region_43wa_7qmu': '21',
#   ':@computed_region_6mkv_f3dw': '21538',
#   ':@computed_region_awaf_s7ux': '15',
#   ':@computed_region_bdys_3d7i': '215',
#   ':@computed_region_vrxf_vc4k': '22',
#   'address': '3063 N MILWAUKEE AVE ',
#   'aka_name': 'MAGNIFICO COFFEE',
#   'city': 'CHICAGO',
#   'dba_name': 'MAGNIFICO COFFEE',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569670',
#   'inspection_type': 'License Re-Inspection',
#   'latitude': '41.93688385568885',
#   'license_': '2818007',
#   'location': {'latitude': '41.93688385568885',
#                'longitude': '-87.71998857609762',
#                'needs_recoding': False},
#   'longitude': '-87.71998857609762',
#   'results': 'Pass w/ Conditions',
#   'risk': 'Risk 2 (Medium)',
#   'state': 'IL',
#   'violations': '3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; '
#                 'KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: FOUND '
#                 'NO EMPLOYEE HEALTH POLICY/TRAINING ON SITE. INSTRUCTED TO '
#                 'PROVIDE A SIGNED EMPLOYEE HEALTH POLICY FOR EACH EMPLOYEE.   '
#                 'PRIORITY FOUNDATION VIOLATION 7-38-010     | 38. INSECTS, '
#                 'RODENTS, & ANIMALS NOT PRESENT - Comments: INSTRUCTED TO '
#                 'RODENT PROOF BOTTOM OF REAR EXIT DOOR.',
#   'zip': '60618'},
#  {':@computed_region_43wa_7qmu': '41',
#   ':@computed_region_6mkv_f3dw': '21560',
#   ':@computed_region_awaf_s7ux': '24',
#   ':@computed_region_bdys_3d7i': '481',
#   ':@computed_region_vrxf_vc4k': '25',
#   'address': '2016 1/2 W DIVISION ST ',
#   'aka_name': 'PICANTE TAQUERIA',
#   'city': 'CHICAGO',
#   'dba_name': 'PICANTE TAQUERIA',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569716',
#   'inspection_type': 'Canvass',
#   'latitude': '41.90328772732953',
#   'license_': '1938696',
#   'location': {'latitude': '41.90328772732953',
#                'longitude': '-87.67798988240148',
#                'needs_recoding': False},
#   'longitude': '-87.67798988240148',
#   'results': 'Out of Business',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'zip': '60622'},
#  {':@computed_region_43wa_7qmu': '46',
#   ':@computed_region_6mkv_f3dw': '21184',
#   ':@computed_region_awaf_s7ux': '41',
#   ':@computed_region_bdys_3d7i': '90',
#   ':@computed_region_vrxf_vc4k': '29',
#   'address': '54 N Hermitage Ave ',
#   'aka_name': 'WILLIAM BROWN ELEMENTARY SCHOOL',
#   'city': 'CHICAGO',
#   'dba_name': 'WILLIAM BROWN ELEMENTARY SCHOOL',
#   'facility_type': 'School',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569645',
#   'inspection_type': 'Canvass',
#   'latitude': '41.88298697688611',
#   'license_': '22351',
#   'location': {'latitude': '41.88298697688611',
#                'longitude': '-87.67071878973897',
#                'needs_recoding': False},
#   'longitude': '-87.67071878973897',
#   'results': 'Pass',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - '
#                 'Comments: OBSERVED LIGHT IN STAFF WASHROOM IN CAFETERIA '
#                 'MANAGERIAL OFFICE NOT WORKING. INSTRUCTED PERSON IN CHARGE TO '
#                 'REPAIR AND MAINTAIN. ',
#   'zip': '60612'},
#  {':@computed_region_43wa_7qmu': '49',
#   ':@computed_region_6mkv_f3dw': '21560',
#   ':@computed_region_awaf_s7ux': '10',
#   ':@computed_region_bdys_3d7i': '543',
#   ':@computed_region_vrxf_vc4k': '25',
#   'address': '2726 W DIVISION ST ',
#   'aka_name': 'LA BRUQUENA RESTAURANT & LOUNGE',
#   'city': 'CHICAGO',
#   'dba_name': 'LA BRUQUENA RESTAURANT & LOUNGE',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569697',
#   'inspection_type': 'Canvass',
#   'latitude': '41.903046386818346',
#   'license_': '1492868',
#   'location': {'latitude': '41.903046386818346',
#                'longitude': '-87.695535129416',
#                'needs_recoding': False},
#   'longitude': '-87.695535129416',
#   'results': 'Pass w/ Conditions',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; '
#                 'KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: '
#                 'OBSERVED NO VERIFIABLE EMPLOYEE HEALTH POLICY ON SITE AT THE '
#                 'TIME OF INSPECTION. LEFT TEMPLATE AND INSTRUCTED TO MAINTAIN '
#                 'COPIES OF EMPLOYEE HEALTH POLICY SIGNED BY ALL EMPLOYEES ON '
#                 'SITE AT ALL TIMES. PRIORITY FOUNDATION VIOLATION 7-38-010. '
#                 'CITATION ISSUED. | 5. PROCEDURES FOR RESPONDING TO VOMITING '
#                 'AND DIARRHEAL EVENTS - Comments: OBSERVED NO KIT AND '
#                 'PROCEDURE ON SITE FOR RESPONDING TO VOMIT AND DIARRHEA. LEFT '
#                 'ONE PAGER AND INSTRUCTED TO MAINTAIN PROCEDURE AND KIT '
#                 'CONTAINING ALL NECESSARY SUPPLIES, INCLUDING A SANITIZER '
#                 'RATED AS EFFECTIVE AGAINST NOROVIRUS ON SITE AT ALL TIMES. '
#                 'PRIORITY FOUNDATION VIOLATION 7-38-005. CITATION ISSUED. | '
#                 '37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER - Comments: '
#                 'OBSERVED A CONTAINER OF BEANS NOT LABELED. INSTRUCTED TO '
#                 'CORRECT. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, '
#                 'PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED '
#                 "LOCK ON STALL IN MEN'S TOILET ROOM DOES NOT WORK. INSTRUCTED "
#                 'TO REPAIR OR REPLACE AND MAINTAIN IN GOOD CONDITION. | 53. '
#                 'TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED '
#                 '- Comments: OBSERVED NO COVERED TRASH RECEPTACLE INSIDE THE '
#                 "WOMEN'S TOILET ROOM. INSTRUCTED TO PROVIDE. | 57. ALL FOOD "
#                 'EMPLOYEES HAVE FOOD HANDLER TRAINING - Comments: OBSERVED 2 '
#                 'FOOD EMPLOYEES WITHOUT FOOD HANDLER TRAINING. INSTRUCTED ALL '
#                 'EMPLOYEES MUST COMPLETE FOOD HANDLER TRAINING AND MAINTAIN '
#                 'RECORDS THEREOF ON SITE AT ALL TIMES. | 58. ALLERGEN TRAINING '
#                 'AS REQUIRED - Comments: OBSERVED NO ALLERGEN TRAINING '
#                 'CERTIFICATES ON SITE AT THE TIME OF INSPECTION. INSTRUCTED '
#                 'ALL EMPLOYEES HOLDING CITY OF CHICAGO FOODSERVICE MANAGER '
#                 'CERTIFICATE MUST COMPLETE ALLERGEN TRAINING AND MAINTAIN '
#                 'RECORDS THEREOF ON SITE AT ALL TIMES.',
#   'zip': '60622'},
#  {':@computed_region_43wa_7qmu': '26',
#   ':@computed_region_6mkv_f3dw': '14917',
#   ':@computed_region_awaf_s7ux': '8',
#   ':@computed_region_bdys_3d7i': '87',
#   ':@computed_region_vrxf_vc4k': '29',
#   'address': '1158 W TAYLOR ST ',
#   'aka_name': 'TAI CHI',
#   'city': 'CHICAGO',
#   'dba_name': 'TAI CHI',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569720',
#   'inspection_type': 'Canvass',
#   'latitude': '41.86952788589461',
#   'license_': '2658576',
#   'location': {'latitude': '41.86952788589461',
#                'longitude': '-87.6565987587843',
#                'needs_recoding': False},
#   'longitude': '-87.6565987587843',
#   'results': 'Pass',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '39. CONTAMINATION PREVENTED DURING FOOD PREPARATION, STORAGE '
#                 '& DISPLAY - Comments: OBSERVED CONTAINERS OF SYRUP STORED '
#                 'INSIDE THE 1ST-FLOOR WASHROOM. INSTRUCTED MANAGEMENT TO '
#                 'REMOVE FROM WASHROOM AND ONLY STORE FOOD IN APPROVED '
#                 'LOCATIONS. | 45. SINGLE-USE/SINGLE-SERVICE ARTICLES: PROPERLY '
#                 'STORED & USED - Comments: OBSERVED A BOX OF SINGLE SERVICE '
#                 'ITEMS (CUPS) STORED DIRECTLY ON THE FLOOR IN THE KITCHEN. '
#                 'MUST ELEVATE AND MAINTAIN. | 51. PLUMBING INSTALLED; PROPER '
#                 'BACKFLOW DEVICES - Comments: OBSERVED NO BACKFLOW PREVENTION '
#                 'DEVICE ON THE 2ND-FLOOR MOP SINK. MUST PROVIDE. | 53. TOILET '
#                 'FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED - '
#                 'Comments: FOUND NO COVERED WASTE RECEPTACLE INSIDE THE '
#                 "2ND-FLOOR WOMEN'S WASHROOM. MUST PROVIDE AND MAINTAIN. | 57. "
#                 'ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING - Comments: '
#                 'OBSERVED FOOD HANDLING EMPLOYEES WITHOUT VALID FOOD HANDLER '
#                 'CERTIFICATES. ALL EMPLOYEES WHO HANDLE/PREPARE FOOD MUST '
#                 'COMPLETE FOOD HANDLER TRAINING AND KEEP CERTIFICATES ON SITE. '
#                 'MUST PROVIDE.',
#   'zip': '60607'},
#  {':@computed_region_43wa_7qmu': '50',
#   ':@computed_region_6mkv_f3dw': '22618',
#   ':@computed_region_awaf_s7ux': '20',
#   ':@computed_region_bdys_3d7i': '259',
#   ':@computed_region_vrxf_vc4k': '15',
#   'address': '4210 N CICERO AVE ',
#   'aka_name': 'I.H.O.P. RESTAURANT',
#   'city': 'CHICAGO',
#   'dba_name': 'I.H.O.P.',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569655',
#   'inspection_type': 'Canvass',
#   'latitude': '41.95742941661818',
#   'license_': '46344',
#   'location': {'latitude': '41.95742941661818',
#                'longitude': '-87.74757441604942',
#                'needs_recoding': False},
#   'longitude': '-87.74757441604942',
#   'results': 'Pass w/ Conditions',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND '
#                 'ACCESSIBLE - Comments: NO HAND SOAP WAS PROVIDED AT THE '
#                 "EXPOSED HAND WASHING SINK AT THE COOK'S PREP LINE.  "
#                 'MANAGEMENT INSTRUCTED TO PROVIDE HAND SOAP AT ALL HAND '
#                 'WASHING SINKS AT ALL TIMES.  PRIORITY FOUNDATION VIOLATION '
#                 '7-38-030(C).  CITATION ISSUED. | 36. THERMOMETERS PROVIDED & '
#                 'ACCURATE - Comments: NO WORKING THERMOMETER WAS PROVIDED IN '
#                 'THE 2 DOOR PREP COOLER ACROSS FROM THE GRILL.  MANAGEMENT '
#                 'INSTRUCTED TO PROVIDE. | 55. PHYSICAL FACILITIES INSTALLED, '
#                 'MAINTAINED & CLEAN - Comments: OBSERVED WATER STAINED CEILING '
#                 'DRYWALL AND UNPAINTED CEILING DRYWALL SECTIONS IN THE DISH '
#                 'WASHING AREA AND ABOVE THE PREP COOLER.  MANAGEMENT '
#                 'INSTRUCTED TO REPAIR AND REPAINT CEILING DRYWALL IN THE '
#                 'AFFECTED AREAS. | 55. PHYSICAL FACILITIES INSTALLED, '
#                 'MAINTAINED & CLEAN - Comments: CLEAN THE FLOOR UNDER THE '
#                 'SINKS AND PREP TABLES IN THE DISH WASHING AREA.  CLEAN THE '
#                 'WALLS OF THE DISH WASHING AREA.',
#   'zip': '60641'},
#  {':@computed_region_43wa_7qmu': '12',
#   ':@computed_region_6mkv_f3dw': '21538',
#   ':@computed_region_awaf_s7ux': '2',
#   ':@computed_region_bdys_3d7i': '23',
#   ':@computed_region_vrxf_vc4k': '16',
#   'address': '3414 W IRVING PARK RD ',
#   'aka_name': 'BURRITO ARCELIANO',
#   'city': 'CHICAGO',
#   'dba_name': 'BURRITO ARCELIANO, INC.',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569650',
#   'inspection_type': 'License Re-Inspection',
#   'latitude': '41.953957216483',
#   'license_': '2886706',
#   'location': {'latitude': '41.953957216483',
#                'longitude': '-87.71355988117966',
#                'needs_recoding': False},
#   'longitude': '-87.71355988117966',
#   'results': 'Pass w/ Conditions',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; '
#                 'KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: '
#                 '2-102.14(O) FOUND NO EMPLOYEE HEALTH POLICY/TRAINING ON SITE. '
#                 'INSTRUCTED TO PROVIDE A SIGNED EMPLOYEE HEALTH POLICY FOR '
#                 'EACH EMPLOYEE.  PRIORITY FOUNDATION VIOLATION 7-38-010 | 55. '
#                 'PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: '
#                 '6-201.16  INSTRUCTED TO REPLACE MISSING FLOOR TILE IN '
#                 'PREP/COOKING AREA AND IN THE DINING AREA. | 58. ALLERGEN '
#                 'TRAINING AS REQUIRED - Comments: 2-102.13  FOUND INCOMPLETE '
#                 'APPROVED ALLERGEN TRAINING CERTIFICATE AVAILABLE. INSTRUCTED '
#                 'ANY PERSON WITH CITY OF CHICAGO FOOD SERVICE SANITATION '
#                 'CERTIFICATE TO COMPLY WITH ALLERGEN TRAINING CERTIFICATION.',
#   'zip': '60618'},
#  {':@computed_region_43wa_7qmu': '46',
#   ':@computed_region_6mkv_f3dw': '22620',
#   ':@computed_region_awaf_s7ux': '41',
#   ':@computed_region_bdys_3d7i': '484',
#   ':@computed_region_vrxf_vc4k': '25',
#   'address': '1443 W Division ',
#   'aka_name': 'Holy Trinity High School',
#   'city': 'CHICAGO',
#   'dba_name': 'Holy Trinity High School',
#   'facility_type': 'School',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569658',
#   'inspection_type': 'Canvass',
#   'latitude': '41.903271671649186',
#   'license_': '1976',
#   'location': {'latitude': '41.903271671649186',
#                'longitude': '-87.66419083256157',
#                'needs_recoding': False},
#   'longitude': '-87.66419083256157',
#   'results': 'Pass w/ Conditions',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND '
#                 'ACCESSIBLE - Comments: FOUND HANDWASHING SINK WATER '
#                 "TEMPERATURE RANGING FROM 71.4F-75.2F, LOCATED IN WOMEN'S 1ST "
#                 'FLOOR WASHROOM AND BOTH 2ND FLOOR WASHROOMS. INSTRUCTED '
#                 'MANAGER TO PROVIDE HOT WATER TEMPERATURE OF 100F-120F AT ALL '
#                 'TIMES. STAFF CORRECTED DURING INSPECTION. THE RESTROOM '
#                 'HANDWASHING SINK WATER IS NOW 100F-120F. PRIORITY VIOLATION. '
#                 '7-38-030(C). CITATION ISSUED. | 15. FOOD SEPARATED AND '
#                 'PROTECTED - Comments: FOUND UNCOVERED PIZZAS STORED IN '
#                 'WALK-IN COOLER. INSTRUCTED TO COVER FOOD TO PREVENT '
#                 'CONTAMINATION. | 47. FOOD & NON-FOOD CONTACT SURFACES '
#                 'CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: '
#                 'FOUND RUSTY PREP CART IN KITCHEN. INSTRUCTED TO REFINISH OR '
#                 'REPLACE TO ENSURE A SMOOTH AND EASY-TO-CLEAN SURFACE AND '
#                 'MAINTENANCE. | 51. PLUMBING INSTALLED; PROPER BACKFLOW '
#                 'DEVICES - Comments: FOUND LEAK AT HOT WATER HANDLE OF '
#                 'BASEMENT, 1ST FLOOR, AND 3RD FLOOR MOP SINKS. INSTRUCTED TO '
#                 'REPAIR AND MAINTAIN. | 55. PHYSICAL FACILITIES INSTALLED, '
#                 'MAINTAINED & CLEAN - Comments: FOUND SOILED MOPS DRYING '
#                 'INSIDE MOP BUCKETS IN MOP SINKS. INSTRUCTED TO HANG TO DRY, '
#                 'AND MAINTAIN. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED '
#                 '& CLEAN - Comments: FOUND CRACKED FLOOR TILES UNDERNEATH '
#                 'SERVING LINE. INSTRUCTED TO REPLACE AND MAINTAIN FOR A SMOOTH '
#                 'AND EASY TO CLEAN SURFACE. ',
#   'zip': '60642'},
#  {':@computed_region_43wa_7qmu': '42',
#   ':@computed_region_6mkv_f3dw': '22212',
#   ':@computed_region_awaf_s7ux': '33',
#   ':@computed_region_bdys_3d7i': '314',
#   ':@computed_region_vrxf_vc4k': '74',
#   'address': '10932 S WESTERN AVE ',
#   'aka_name': 'OPEN OUTCRY BREWING',
#   'city': 'CHICAGO',
#   'dba_name': 'OPEN OUTCRY BREWING',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569693',
#   'inspection_type': 'Canvass',
#   'latitude': '41.69462309445644',
#   'license_': '2808516',
#   'location': {'latitude': '41.69462309445644',
#                'longitude': '-87.68139382337692',
#                'needs_recoding': False},
#   'longitude': '-87.68139382337692',
#   'results': 'Pass w/ Conditions',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOWLEDGE, AND '
#                 'PERFORMS DUTIES - Comments: OBSERVED NO PERSON IN CHARGE WITH '
#                 'VALID CHICAGO FOOD SANITATION CERTIFICATE. INSTRUCTED MANAGER '
#                 'TO DESIGNATE PERSON IN CHARGE DURING ALL HOURS OF OPERATION. '
#                 'PRIORITY FOUNDATION  | 2. CITY OF CHICAGO FOOD SERVICE '
#                 'SANITATION CERTIFICATE - Comments: OBSERVED NO CHICAGO FOOD '
#                 'SANITATION MANAGER ON SITE OR VALID CERTIFICATE POSTED WHEN '
#                 'TCS FOOD(SOUP 160.2F) PREPARED AND SERVED. A CHICAGO FOOD '
#                 'SANITATION MANAGER MUST BE ON SITE AND VALID CERTIFICATE '
#                 'POSTED AT ALL TIMES TCS FOOD PREPARED AND SERVED. PRIORITY '
#                 'FOUNDATION 7-38-012 CITATION ISSUED | 40. PERSONAL '
#                 'CLEANLINESS - Comments: OBSERVED FOOD HANDLER NOT WEARING '
#                 'HAIR RESTRAINT. ALL FOOD HANDLERS MUST WEAR EFFECTIVE HAIR '
#                 'RESTRAINTS. | 58. ALLERGEN TRAINING AS REQUIRED - Comments: '
#                 'OBSERVED NO ALLERGEN TRAINING FOR CERTIFIED MANAGER ON DUTY. '
#                 'INSTRUCTED MANAGER TO PROVIDE ALLERGEN TRAINING FOR ALL '
#                 'CERTIFIED MANAGERS.',
#   'zip': '60643'},
#  {':@computed_region_43wa_7qmu': '24',
#   ':@computed_region_6mkv_f3dw': '21849',
#   ':@computed_region_awaf_s7ux': '46',
#   ':@computed_region_bdys_3d7i': '28',
#   ':@computed_region_vrxf_vc4k': '6',
#   'address': '2701 W FOSTER AVE ',
#   'aka_name': 'BUDLONG ELEMENTARY SCHOOL',
#   'city': 'CHICAGO',
#   'dba_name': 'LYMAN A BUDLONG ELEMENTARY',
#   'facility_type': 'School',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569679',
#   'inspection_type': 'Canvass',
#   'latitude': '41.97572651851171',
#   'license_': '22391',
#   'location': {'latitude': '41.97572651851171',
#                'longitude': '-87.69660442713682',
#                'needs_recoding': False},
#   'longitude': '-87.69660442713682',
#   'results': 'Fail',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND '
#                 'ACCESSIBLE - Comments: OBSERVED HAND WASHING SINK WITH HOSE '
#                 'TIED UP TO IT. INSTRUCTED MANAGER TO REMOVE HOSE AND ENSURE '
#                 'THE HAND WASHING SINK IS FOR HAND WASHING ONLY. MANAGER '
#                 'REMOVED HOSE. PRIORITY FOUNDATION VIOLATION 7-38-030(C) NO '
#                 'CITATION ISSUED. | 22. PROPER COLD HOLDING TEMPERATURES - '
#                 'Comments: OBSERVED MOZZARELLA CHEESE STICKS HELD AT AN '
#                 'INADEQUATE TEMPERATURE OF 47 F. INSTRUCTED MANAGER TO ENSURE '
#                 'ALL COLD TCS FOODS ARE HELD AT AN ADEQUATE TEMPERATURE OF 41 '
#                 'F AND BELOW. MANAGER DISCARDED 4 POUNDS OF MOZZARELLA CHEESE '
#                 'STICKS ($15) PRIORITY VIOLATION 7-38-005 NO CITATION ISSUED.  '
#                 '| 51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: '
#                 "OBSERVED NO HOT WATER IN RIGHT SINK IN GIRL'S TOILET ROOM ON "
#                 '2ND FLOOR. HOT WATER IN RIGHT SINK WAS MEASURED AT 100 F. '
#                 'INSTRUCTED MANAGER TO PROVIDE HOT WATER WITH A MINIMUM '
#                 'TEMPERATURE OF 100 F TO ALL HAND WASHING SINKS | 51. PLUMBING '
#                 'INSTALLED; PROPER BACKFLOW DEVICES - Comments: OBSERVED LEAK '
#                 'IN FAUCET OF 3 COMPARTMENT SINK WHEN WATER IS RAN. INSTRUCTED '
#                 'MANAGER TO REPAIR LEAK | 52. SEWAGE & WASTE WATER PROPERLY '
#                 'DISPOSED - Comments: OBSERVED INADEQUATE WASTE WATER DISPOSAL '
#                 'AT THREE COMPARTMENT SINK. WHEN ONE COMPARTMENT DRAINS '
#                 'ANOTHER ONE FLOODS BEFORE GOING BACK DOWN. INSTRUCTED MANAGER '
#                 'TO SERVICE 3 COMPARTMENT SINK. PRIORITY VIOLATION 7-38-030 '
#                 '(C). NO CITATION ISSUED | 60. PREVIOUS CORE VIOLATION '
#                 'CORRECTED - Comments: OBSERVED PREVIOUS CORE VIOLATION NOT '
#                 'CORRECTED WITHIN SPECIFIED TIMEFRAME. REPORT #2546571 DATED '
#                 'JANUARY 18TH 2022 INSTRUCTED FACILITY TO REPAINT GREASE TRAP '
#                 'UNDERNEATH 3 COMPARTMENT SINK WITH EXCESSIVE RUST '
#                 'ACCUMULATION BY APRIL 18TH 2022. OBSERVED GREASE TRAP WITH '
#                 'EXCESSIVE RUST ACCUMULATION. INSTRUCTED MANAGER TO PAINT '
#                 'GREASE TRAP. PRIORITY FOUNDATION VIOLATION 7-42-090 NO '
#                 'CITATION ISSUED.',
#   'zip': '60625'},
#  {':@computed_region_43wa_7qmu': '16',
#   ':@computed_region_6mkv_f3dw': '22616',
#   ':@computed_region_awaf_s7ux': '40',
#   ':@computed_region_bdys_3d7i': '634',
#   ':@computed_region_vrxf_vc4k': '31',
#   'address': '4925 N BROADWAY ',
#   'aka_name': 'THAI PASTRY',
#   'city': 'CHICAGO',
#   'dba_name': 'THAI PASTRY',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569682',
#   'inspection_type': 'Canvass',
#   'latitude': '41.97221355699091',
#   'license_': '2713340',
#   'location': {'latitude': '41.97221355699091',
#                'longitude': '-87.6596091001073',
#                'needs_recoding': False},
#   'longitude': '-87.6596091001073',
#   'results': 'Pass',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '16. FOOD-CONTACT SURFACES: CLEANED & SANITIZED - Comments: '
#                 'OBSERVED THE INTERIOR OF THE ICE MACHINE BIN AND INTERIOR '
#                 'GUARD WITH SOME DIRT, NOT CLEAN. INSTRUCTED THE PERSON IN '
#                 'CHARGE TO DETAIL CLEANING AND MAINTAIN. | 39. CONTAMINATION '
#                 'PREVENTED DURING FOOD PREPARATION, STORAGE & DISPLAY - '
#                 'Comments: OBSERVED BOWLS AND OTHER UTENSILS STORED FACING UP '
#                 'ON THE SHELF IN THE REAR PREPARATION  AREA. INSTRUCTED THE '
#                 'PERSON IN CHARGE TO INVERT ALL BOWLS AND UTENSILS TO PREVENT '
#                 'CONTAMINATION. | 55. PHYSICAL FACILITIES INSTALLED, '
#                 'MAINTAINED & CLEAN - Comments: OBSERVED UNUSED EQUIPMENT '
#                 '(DEEP FRYER) BEING STORED NEAR THE REAR EXIT DOOR. INSTRUCTED '
#                 'THE PERSON IN CHARGE TO REMOVE UNUSED ITEMS TO PREVENT '
#                 'POTENTIAL PEST HARBORAGE.',
#   'zip': '60640'},
#  {':@computed_region_43wa_7qmu': '16',
#   ':@computed_region_6mkv_f3dw': '22616',
#   ':@computed_region_awaf_s7ux': '40',
#   ':@computed_region_bdys_3d7i': '634',
#   ':@computed_region_vrxf_vc4k': '31',
#   'address': '4941 N BROADWAY ',
#   'aka_name': 'PHO VIET',
#   'city': 'CHICAGO',
#   'dba_name': 'PHO VIET',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569712',
#   'inspection_type': 'Canvass',
#   'latitude': '41.97270688665208',
#   'license_': '1868847',
#   'location': {'latitude': '41.97270688665208',
#                'longitude': '-87.6596216050827',
#                'needs_recoding': False},
#   'longitude': '-87.6596216050827',
#   'results': 'Pass',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '39. CONTAMINATION PREVENTED DURING FOOD PREPARATION, STORAGE '
#                 '& DISPLAY - Comments: OBSERVED FOOD ITEMS STORED ON THE FLOOR '
#                 'IN THE WALK-IN COOLER LOCATED IN THE REAR.  INSTRUCTED THE '
#                 'PERSON IN CHARGE TO ELEVATE ALL FOOD SIX INCHES OFF THE '
#                 'FLOOR. | 43. IN-USE UTENSILS: PROPERLY STORED - Comments: '
#                 'OBSERVED ICE SCOOP LAYING ON TOP OF ICE INSIDE ICE MACHINE. '
#                 'INSTRUCTED THE PERSON IN CHARGE TO STORE THE ICE SCOOP IN A '
#                 'CLEAN AND SANITIZED CONTAINER TO PREVENT POTENTIAL '
#                 'CONTAMINATION | 47. FOOD & NON-FOOD CONTACT SURFACES '
#                 'CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: '
#                 'OBSERVED CUTTING BOARDS ON PREP TABLES WITH DEEP SCRATCHES '
#                 'AND STAINS. INSTRUCTED THE PERSON IN CHARGE TO RESURFACE OR '
#                 'REPLACE CUTTING BOARDS. | 55. PHYSICAL FACILITIES INSTALLED, '
#                 'MAINTAINED & CLEAN - Comments: OBSERVED UNUSED ITEMS (TABLES, '
#                 'BOXES, BIKES) BEING STORED ON THE SIDE OF THE BAR. INSTRUCTED '
#                 'THE PERSON IN CHARGE TO REMOVE UNUSED ITEMS TO PREVENT '
#                 'POTENTIAL PEST HARBORAGE. | 56. ADEQUATE VENTILATION & '
#                 'LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED A '
#                 'MISSING LIGHT SHIELD FOR THE LIGHT ABOVE 2 DOOR FREEZER, '
#                 'LOCATED IN THE REAR PREPARATION AREA. INSTRUCTED THE PERSON '
#                 'IN CHARGE TO PROVIDE A LIGHT SHIELD  AND MAINTAIN IT AT ALL '
#                 'TIMES. | 58. ALLERGEN TRAINING AS REQUIRED - Comments: '
#                 'OBSERVED CERTIFIED FOOD MANAGER WITHOUT ALLERGEN AWARENESS '
#                 'TRAINING CERTIFICATE. INSTRUCTED THE PERSON IN CHARGE TO '
#                 'ENSURE THAT ANY INDIVIDUAL THAT HOLDS A CITY OF CHICAGO '
#                 'FOODSERVICE MANAGER CERTIFICATE COMPLETES ALLERGEN AWARENESS '
#                 'TRAINING AND OBTAINS ALLERGEN AWARENESS CERTIFICATE.\t',
#   'zip': '60640'},
#  {':@computed_region_43wa_7qmu': '46',
#   ':@computed_region_6mkv_f3dw': '22620',
#   ':@computed_region_awaf_s7ux': '41',
#   ':@computed_region_bdys_3d7i': '522',
#   ':@computed_region_vrxf_vc4k': '25',
#   'address': '925 W CHICAGO AVE ',
#   'aka_name': 'AGLAIA COFFEE AND TEA COMPANY',
#   'city': 'CHICAGO',
#   'dba_name': 'AGLAIA COFFEE AND TEA COMPANY',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569703',
#   'inspection_type': 'Canvass',
#   'latitude': '41.89623151378124',
#   'license_': '2749668',
#   'location': {'latitude': '41.89623151378124',
#                'longitude': '-87.65082896270799',
#                'needs_recoding': False},
#   'longitude': '-87.65082896270799',
#   'results': 'Pass',
#   'risk': 'Risk 2 (Medium)',
#   'state': 'IL',
#   'violations': '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY '
#                 'DESIGNED, CONSTRUCTED & USED - Comments: FOUND RAW WOOD '
#                 'SHELVING ADJACENT TO THE FRONT HANDWASHING SINK. INSTRUCTED '
#                 'TO PAINT/SEAL TO ENSURE A SMOOTH, NONABSORBANT, AND '
#                 'EASY-TO-CLEAN SURFACE. MAINTAIN. | 51. PLUMBING INSTALLED; '
#                 'PROPER BACKFLOW DEVICES - Comments: FOUND LEFT HANDLE OF '
#                 'FRONT HANDWASHING SINK IN POOR REPAIR. INSTRUCTED TO REPAIR '
#                 'AND MAINTAIN. | 53. TOILET FACILITIES: PROPERLY CONSTRUCTED, '
#                 'SUPPLIED, & CLEANED - Comments: FOUND NO COVERED RECEPTACLE '
#                 'IN UNISEX RESTROOM. INSTRUCTED TO OBTAIN AND MAINTAIN. | 55. '
#                 'PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: '
#                 'FOUND ITEMS STORED ON FLOOR UNDER REAR PREP TABLE. INSTRUCTED '
#                 "TO ELEVATE ALL ITEMS AT LEAST 6' OFF FLOOR FOR EASE OF "
#                 'CLEANING, MAINTAIN. | 55. PHYSICAL FACILITIES INSTALLED, '
#                 'MAINTAINED & CLEAN - Comments: FOUND DEBRIS ACCUMULATED IN '
#                 'FLOOR DRAIN BEHIND SALES COUNTER. INSTRUCTED TO CLEAN AND '
#                 'MAINTAIN.',
#   'zip': '60642'},
#  {':@computed_region_43wa_7qmu': '23',
#   ':@computed_region_6mkv_f3dw': '22216',
#   ':@computed_region_awaf_s7ux': '11',
#   ':@computed_region_bdys_3d7i': '696',
#   ':@computed_region_vrxf_vc4k': '26',
#   'address': '4753-4759 W WASHINGTON BLVD ',
#   'aka_name': 'THE PLAY PIN',
#   'city': 'CHICAGO',
#   'dba_name': 'THE PLAY PIN',
#   'facility_type': 'Daycare Above and Under 2 Years',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569692',
#   'inspection_type': 'License Re-Inspection',
#   'latitude': '41.88170868173873',
#   'license_': '2602233',
#   'location': {'latitude': '41.88170868173873',
#                'longitude': '-87.74498503875053',
#                'needs_recoding': False},
#   'longitude': '-87.74498503875053',
#   'results': 'Pass',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - '
#                 'Comments: OBSERVED SOILED MOP HEAD NOT PROPERLY STORED. '
#                 'INSTRUCTED MANAGER TO HANG MOP HEADS TO PREVENT INSECT '
#                 'BREEDING.',
#   'zip': '60644'},
#  {':@computed_region_43wa_7qmu': '6',
#   ':@computed_region_6mkv_f3dw': '22248',
#   ':@computed_region_awaf_s7ux': '35',
#   ':@computed_region_bdys_3d7i': '793',
#   ':@computed_region_vrxf_vc4k': '60',
#   'address': '5320 S PULASKI RD ',
#   'aka_name': 'JEWEL / OSCO',
#   'city': 'CHICAGO',
#   'dba_name': 'JEWEL FOOD STORE #3170',
#   'facility_type': 'Grocery Store',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569719',
#   'inspection_type': 'Canvass',
#   'latitude': '41.796197591415535',
#   'license_': '1366',
#   'location': {'latitude': '41.796197591415535',
#                'longitude': '-87.72339188344549',
#                'needs_recoding': False},
#   'longitude': '-87.72339188344549',
#   'results': 'Pass',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: '
#                 'OBSERVED A GAP ALONG THE TOP OF OSCO DELIVERY DOOR MUST MAKE '
#                 'DOOR TIGHT FITTING. | 49. NON-FOOD/FOOD CONTACT SURFACES '
#                 'CLEAN - Comments: MUST CLEAN EXTERIOR OF GREASE TRAP AT 3- '
#                 'COMP SINK | 51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - '
#                 'Comments: 5-205.15 LOOSE LID ON GREASE TRAP AT 3- COMP SINK '
#                 'AT DELI AREA. INSTD TO REPAIR OR REPLACE AND MAINTAIN | 55. '
#                 'PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: '
#                 '6-201.11 MUST REPAIR OR REPLACE STAINED,MISSING AND DAMAGED '
#                 'CEILING TILES IN REAR DRY STORAGE AREA,BAKERY AREA-STAINED '
#                 'CEILING TILE NEAR DISH MACHINE & DAMAGED WALL TRIM IN SAME '
#                 'AREA. | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS '
#                 'USED - Comments: 6-202.11: MUST REPLACE CRACKED LIGHT SHIELD '
#                 'IN MEAT PROCESSING AREA.MUST REPAIR OR REPLACE BURNTOUT '
#                 'LIGHTS IN DELI WALK IN COOLER,PRODUCE WALK IN COOLER,MARKET '
#                 'WALK IN FREEZER.',
#   'zip': '60632'},
#  {':@computed_region_43wa_7qmu': '41',
#   ':@computed_region_6mkv_f3dw': '22535',
#   ':@computed_region_awaf_s7ux': '15',
#   ':@computed_region_bdys_3d7i': '386',
#   ':@computed_region_vrxf_vc4k': '23',
#   'address': '3129 W ARMITAGE AVE ',
#   'aka_name': 'SUBWAY',
#   'city': 'CHICAGO',
#   'dba_name': 'SUBWAY',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569649',
#   'inspection_type': 'Canvass',
#   'latitude': '41.91729424455668',
#   'license_': '2003331',
#   'location': {'latitude': '41.91729424455668',
#                'longitude': '-87.70654528949485',
#                'needs_recoding': False},
#   'longitude': '-87.70654528949485',
#   'results': 'Pass',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - '
#                 'Comments: CUSTOMERS WASHROOM FLOOR DRAIN COVER LOOSE. MUST '
#                 'REATTACH FLOOR DRAIN COVER.',
#   'zip': '60647'},
#  {':@computed_region_43wa_7qmu': '46',
#   ':@computed_region_6mkv_f3dw': '22620',
#   ':@computed_region_awaf_s7ux': '41',
#   ':@computed_region_bdys_3d7i': '522',
#   ':@computed_region_vrxf_vc4k': '25',
#   'address': '942 W HURON ST ',
#   'aka_name': 'GLAZED AND INFUSED',
#   'city': 'CHICAGO',
#   'dba_name': 'GLAZED AND INFUSED',
#   'facility_type': 'Bakery',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569724',
#   'inspection_type': 'Canvass',
#   'latitude': '41.89513208866283',
#   'license_': '2550116',
#   'location': {'latitude': '41.89513208866283',
#                'longitude': '-87.65181321584753',
#                'needs_recoding': False},
#   'longitude': '-87.65181321584753',
#   'results': 'Out of Business',
#   'risk': 'Risk 2 (Medium)',
#   'state': 'IL',
#   'zip': '60642'},
#  {':@computed_region_43wa_7qmu': '20',
#   ':@computed_region_6mkv_f3dw': '21849',
#   ':@computed_region_awaf_s7ux': '2',
#   ':@computed_region_bdys_3d7i': '118',
#   ':@computed_region_vrxf_vc4k': '14',
#   'address': '4702 N KIMBALL AVE ',
#   'aka_name': 'KBM GRILL',
#   'city': 'CHICAGO',
#   'dba_name': 'KBM GRILL',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2023-01-13T00:00:00.000',
#   'inspection_id': '2569641',
#   'inspection_type': 'Canvass',
#   'latitude': '41.96672764378098',
#   'license_': '2835026',
#   'location': {'latitude': '41.96672764378098',
#                'longitude': '-87.7134599424416',
#                'needs_recoding': False},
#   'longitude': '-87.7134599424416',
#   'results': 'Out of Business',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
# ...
#                 'BULK ITEMS NOT IN ORIGINAL CONTAINER WITH COMMON NAME AND '
#                 'MAINTAIN. | 57. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING '
#                 '- Comments:  OBSERVED NO FOOD HANDLER TRAINING CERTIFICATES '
#                 'ON SITE FOR FOOD HANDLER EMPLOYEE. INSTRUCTED PERSON IN '
#                 'CHARGE TO DIRECT FOOD HANDLER EMPLOYEES TO OBTAIN TRAINING '
#                 'AND RETAIN CERTIFICATES ON SITE.',
#   'zip': '60623'},
#  {':@computed_region_43wa_7qmu': '26',
#   ':@computed_region_6mkv_f3dw': '21194',
#   ':@computed_region_awaf_s7ux': '8',
#   ':@computed_region_bdys_3d7i': '3',
#   ':@computed_region_vrxf_vc4k': '35',
#   'address': '2245 S WENTWORTH AVE ',
#   'aka_name': 'CHICAGO FOOD MARKET INC',
#   'city': 'CHICAGO',
#   'dba_name': 'CHICAGO FOOD MARKET INC',
#   'facility_type': 'Grocery Store',
#   'inspection_date': '2022-12-15T00:00:00.000',
#   'inspection_id': '2568566',
#   'inspection_type': 'Complaint',
#   'latitude': '41.851595719946424',
#   'license_': '19708',
#   'location': {'latitude': '41.851595719946424',
#                'longitude': '-87.6318369065422',
#                'needs_recoding': False},
#   'longitude': '-87.6318369065422',
#   'results': 'Pass',
#   'risk': 'Risk 2 (Medium)',
#   'state': 'IL',
#   'violations': '41. WIPING CLOTHS: PROPERLY USED & STORED - Comments: '
#                 'OBSERVED WIPING CLOTH ON COUNTER WHEN NOT IN USE. INSTRUCTED '
#                 'TO PROVIDE CLEAN SANITIZING SOLUTION FOR TOWELS WHEN NOT IN '
#                 'USE.  | 49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: '
#                 'ALL REACH IN FOOD CASES IN NEED OF CLEANING TO REMOVE ALL '
#                 'FOOD SPLATTERS. INSTRUCTED TO CLEAN AND MAINTAIN  | 55. '
#                 'PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: '
#                 'FLOORS IN NEED OF CLEANING TO REMOVE ALL FOOD SPILLS  '
#                 'INSTRUCTED TO CLEAN AND MAINTAIN ',
#   'zip': '60616'},
#  {':@computed_region_43wa_7qmu': '19',
#   ':@computed_region_6mkv_f3dw': '22254',
#   ':@computed_region_awaf_s7ux': '25',
#   ':@computed_region_bdys_3d7i': '392',
#   ':@computed_region_vrxf_vc4k': '17',
#   'address': '3950 N HARLEM AVE ',
#   'aka_name': 'FALAFEL DREAM',
#   'city': 'CHICAGO',
#   'dba_name': 'FALAFEL DREAM, INC.',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2022-12-15T00:00:00.000',
#   'inspection_id': '2568549',
#   'inspection_type': 'Canvass Re-Inspection',
#   'latitude': '41.95225488946834',
#   'license_': '2437219',
#   'location': {'latitude': '41.95225488946834',
#                'longitude': '-87.80739690900613',
#                'needs_recoding': False},
#   'longitude': '-87.80739690900613',
#   'results': 'Pass',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: FOUND '
#                 'FOLLOWING NOT CLEAN: EXHAUST HOOD.MUST CLEAN. | 58. ALLERGEN '
#                 'TRAINING AS REQUIRED - Comments: FOUND SANITATION MANAGER '
#                 'WITH NO ALLERGEN TRAINING.MUST PROVIDE.',
#   'zip': '60634'},
#  {':@computed_region_43wa_7qmu': '21',
#   ':@computed_region_6mkv_f3dw': '22618',
#   ':@computed_region_awaf_s7ux': '27',
#   ':@computed_region_bdys_3d7i': '71',
#   ':@computed_region_vrxf_vc4k': '22',
#   'address': '2959 N PULASKI RD ',
#   'aka_name': 'CAFE FENIX',
#   'city': 'CHICAGO',
#   'dba_name': 'CAFE FENIX',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2022-12-15T00:00:00.000',
#   'inspection_id': '2568586',
#   'inspection_type': 'Canvass',
#   'latitude': '41.93533365394091',
#   'license_': '2621517',
#   'location': {'latitude': '41.93533365394091',
#                'longitude': '-87.72693021132564',
#                'needs_recoding': False},
#   'longitude': '-87.72693021132564',
#   'results': 'Pass',
#   'risk': 'Risk 2 (Medium)',
#   'state': 'IL',
#   'violations': '39. CONTAMINATION PREVENTED DURING FOOD PREPARATION, STORAGE '
#                 '& DISPLAY - Comments: OBSERVED BOWLS AND OTHER UTENSILS '
#                 'STORED FACING UP ON SHELVING UNIT IN REAR PREPARATION AREA. '
#                 'INSTRUCTED  THE PERSON IN CHARGE TO INVERT ALL EQUIPMENT TO '
#                 'PREVENT CONTAMINATION. | 55. PHYSICAL FACILITIES INSTALLED, '
#                 'MAINTAINED & CLEAN - Comments: OBSERVED VENT COVERS  WITH '
#                 'DUST ACCUMULATION IN ALL TOILET ROOMS. INSTRUCTED THE PERSON '
#                 'IN CHARGE TO REMOVE DUST AND MAINTAIN.',
#   'zip': '60641'},
#  {':@computed_region_43wa_7qmu': '35',
#   ':@computed_region_6mkv_f3dw': '21546',
#   ':@computed_region_awaf_s7ux': '9',
#   ':@computed_region_bdys_3d7i': '472',
#   ':@computed_region_vrxf_vc4k': '43',
#   'address': '9130 S University (1132E) ',
#   'aka_name': 'Washington, Harold',
#   'city': 'CHICAGO',
#   'dba_name': 'Washington, Harold',
#   'facility_type': 'School',
#   'inspection_date': '2022-12-15T00:00:00.000',
#   'inspection_id': '2568547',
#   'inspection_type': 'Canvass Re-Inspection',
#   'latitude': '41.72853491662006',
#   'license_': '24921',
#   'location': {'latitude': '41.72853491662006',
#                'longitude': '-87.59629326944139',
#                'needs_recoding': False},
#   'longitude': '-87.59629326944139',
#   'results': 'Fail',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '52. SEWAGE & WASTE WATER PROPERLY DISPOSED - Comments: '
#                 '5-402.13 OBSERVED INADEQUATE WASTE WATER DISPOSAL AT THREE '
#                 'COMPARTMENT SINK. WHEN ONE COMPARTMENT DRAINS ANOTHER ONE '
#                 'FLOODS. INSTRUCTED MANAGER TO SERVICE 3 COMPARTMENT SINK.  '
#                 'PRIORITY VIOLATION 7-38-030 (C). NO CITATION ISSUED',
#   'zip': '60619'},
#  {':@computed_region_43wa_7qmu': '30',
#   ':@computed_region_6mkv_f3dw': '4300',
#   ':@computed_region_awaf_s7ux': '6',
#   ':@computed_region_bdys_3d7i': '243',
#   ':@computed_region_vrxf_vc4k': '69',
#   'address': '8243 S KEDZIE AVE ',
#   'aka_name': 'A TO Z WHOLESALE GROCERY & TOBACCO',
#   'city': 'CHICAGO',
#   'dba_name': 'A TO Z WHOLESALE GROCERY & TOBACCO',
#   'facility_type': 'Grocery Store',
#   'inspection_date': '2022-12-15T00:00:00.000',
#   'inspection_id': '2568554',
#   'inspection_type': 'Canvass',
#   'latitude': '41.74304202408357',
#   'license_': '2822665',
#   'location': {'latitude': '41.74304202408357',
#                'longitude': '-87.70206459428091',
#                'needs_recoding': False},
#   'longitude': '-87.70206459428091',
#   'results': 'Pass',
#   'risk': 'Risk 2 (Medium)',
#   'state': 'IL',
#   'violations': '36. THERMOMETERS PROVIDED & ACCURATE - Comments: MISSING '
#                 'THERMOMETERS IN REFRIGERATORS. INSTD TO PROVIDE AND MAINTAIN '
#                 '| 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY '
#                 'DESIGNED, CONSTRUCTED & USED - Comments: RAW WOOD STORAGE '
#                 'SHELVES AT BOTTOM OF PREP TABLE. INSTD TO SEAL SAME SO AS '
#                 'SURFACE TO BE SMOOTH, EVEN AND EASILY CLEANABLE | 55. '
#                 'PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: '
#                 'UNFINISHED DRY WALL IN TOILET ROOM. INSTD TO FINISH WALL AND '
#                 'MAINTAIN',
#   'zip': '60652'},
#  {':@computed_region_43wa_7qmu': '13',
#   ':@computed_region_6mkv_f3dw': '21554',
#   ':@computed_region_awaf_s7ux': '18',
#   ':@computed_region_bdys_3d7i': '533',
#   ':@computed_region_vrxf_vc4k': '70',
#   'address': '847-853 W 87TH ST ',
#   'aka_name': 'BUY LOW FOOD & LIQUOR',
#   'city': 'CHICAGO',
#   'dba_name': 'BUY LOW FOOD & LIQUOR',
#   'facility_type': 'Grocery Store',
#   'inspection_date': '2022-12-14T00:00:00.000',
#   'inspection_id': '2568496',
#   'inspection_type': 'Canvass Re-Inspection',
#   'latitude': '41.73593936167209',
#   'license_': '1969368',
#   'location': {'latitude': '41.73593936167209',
#                'longitude': '-87.64533317498139',
#                'needs_recoding': False},
#   'longitude': '-87.64533317498139',
#   'results': 'Fail',
#   'risk': 'Risk 3 (Low)',
#   'state': 'IL',
#   'violations': '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY '
#                 'DESIGNED, CONSTRUCTED & USED - Comments: Inspector Comments: '
#                 'Inspector Comments: MUST ELIMINATE CRATES USED FOR STORAGE '
#                 'THROUGHOUT AND PROVIDE ADEQUATE SHELVING UNITS.MUST REMOVE '
#                 'RUST FROM SOME DISPLAY SHELVES ON SALES FLOOR AND BEHIND '
#                 'SERVICE COUNTER. | 49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - '
#                 'Comments: Inspector Comments: Inspector Comments: MUST CLEAN '
#                 'DUST & DIRT BUILD UP FROM OVERHEAD CIGARETTE CADDY,DISPLAY '
#                 'SHELVES THROUGHOUT,WALK IN COOLER -FANGUARD COVERS, DRINK '
#                 'SLEEVES & SHELVING UNITS,COMPRESSOR UNITS. | 55. PHYSICAL '
#                 'FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: '
#                 'Inspector Comments: Inspector Comments: MUST REMOVE EXCESSIVE '
#                 'CLUTTER FROM ALONG WALLS IN REAR STORAGE AREAS ,FRONT SERVICE '
#                 'COUNTER AND SALES FLOOR AND ON TOP & IN BETWEEN WALL OF  BEER '
#                 'WALK IN COOLER IN REAR STORAGE. | 55. PHYSICAL FACILITIES '
#                 'INSTALLED, MAINTAINED & CLEAN - Comments: Inspector Comments: '
#                 'Inspector Comments: MUST REPAIR OR REPLACE DAMAGED FLOOR '
#                 'TILES THROUGHOUT REAR LIQUOR AREAS AND SERVICE COUNTER. | 59. '
#                 'PREVIOUS PRIORITY FOUNDATION VIOLATION CORRECTED - Comments: '
#                 'STILL OBSERVED EVIDENCE OF APPX. 60 OR MORE MICE DROPPINGS ON '
#                 'SALES FLOOR NEAR GAMBLING MACHINE, IN FRONT OF REACH IN '
#                 'COOLER DOORS,ON FLOOR BEHIND SERVICE COUNTER BY WINDOW, REAR '
#                 'STORAGE AREA ALONG WALL BASES AND PALLETS. MUST REMOVE '
#                 'DROPPINGS CLEAN AND SANITIZE AREAS. MUST HAVE A PEST CONTROL '
#                 'OPERATOR TO SERVICE PREMISES ON OR AFTER 12/14/22.(PRIORITY '
#                 '7-42-090)',
#   'zip': '60620'},
#  {':@computed_region_43wa_7qmu': '3',
#   ':@computed_region_6mkv_f3dw': '14924',
#   ':@computed_region_awaf_s7ux': '53',
#   ':@computed_region_bdys_3d7i': '740',
#   ':@computed_region_vrxf_vc4k': '59',
#   'address': '1707 W 47TH ST ',
#   'aka_name': 'TORTILLERIA ATOTONILCO, INC',
#   'city': 'CHICAGO',
#   'dba_name': 'TORTILLERIA ATOTONILCO, INC',
#   'facility_type': 'Wholesale',
#   'inspection_date': '2022-12-14T00:00:00.000',
#   'inspection_id': '2568517',
#   'inspection_type': 'Complaint Re-Inspection',
#   'latitude': '41.80846879520972',
#   'license_': '7722',
#   'location': {'latitude': '41.80846879520972',
#                'longitude': '-87.6677274811442',
#                'needs_recoding': False},
#   'longitude': '-87.6677274811442',
#   'results': 'Fail',
#   'risk': 'Risk 2 (Medium)',
#   'state': 'IL',
#   'violations': '57. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING - Comments: '
#                 'FOUND NO FOOD HANDLER TRAINING ON SITE. INSTRUCTED MANAGER TO '
#                 'PROVIDE PROOF OF FOOD HANDLER TRAINING FOR ALL EMPLOYEES.  | '
#                 '59. PREVIOUS PRIORITY FOUNDATION VIOLATION CORRECTED - '
#                 'Comments: OBSERVED PREVIOUS PRIORITY FOUNDATION VIOLATION NOT '
#                 'CORRECTED FROM REPORT #2565949 DATED: 10/26/22, WITH '
#                 'RE-INSPECTION DATE OF 11/02/22, AND ADDITIONAL EXTENSION '
#                 'GRANTED UNTIL 12/12/2022; #55 FOUND UNSEALED CEMENT FLOORS '
#                 'THROUGHOUT FACILITY. MUST PROVIDE FLOORS CEILINGS AND WALLS '
#                 'THAT ARE SMOOTH AND EASILY CLEANABLE. INTSTRUCTED PERSON IN '
#                 'CHARGE TO CORRECT VIOLATION IN ITS ENTIRETY AND MAINTAIN. '
#                 'PRIORITY VIOLATION #7-42-090. CITATION ISSUED.',
#   'zip': '60609'},
#  {':@computed_region_43wa_7qmu': '1',
#   ':@computed_region_6mkv_f3dw': '21569',
#   ':@computed_region_awaf_s7ux': '29',
#   ':@computed_region_bdys_3d7i': '124',
#   ':@computed_region_vrxf_vc4k': '32',
#   'address': '2801 S KEDZIE AVE ',
#   'aka_name': 'DUNKIN DONUTS/BASKIN ROBBINS',
#   'city': 'CHICAGO',
#   'dba_name': 'DUNKIN DONUTS',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2022-12-14T00:00:00.000',
#   'inspection_id': '2568530',
#   'inspection_type': 'Canvass',
#   'latitude': '41.84081413121831',
#   'license_': '32316',
#   'location': {'latitude': '41.84081413121831',
#                'longitude': '-87.70478142929927',
#                'needs_recoding': False},
#   'longitude': '-87.70478142929927',
#   'results': 'Pass w/ Conditions',
#   'risk': 'Risk 2 (Medium)',
#   'state': 'IL',
#   'violations': '1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOWLEDGE, AND '
#                 'PERFORMS DUTIES - Comments: OBSERVED NO PERSON ON SITE WITH '
#                 'FOODSERVICE SANITATION MANAGEMENT TRAINING AT TIME OF '
#                 'INSPECTION.  | 2. CITY OF CHICAGO FOOD SERVICE SANITATION '
#                 'CERTIFICATE - Comments: OBSERVED FACILITY FOOD HANDLERS '
#                 'PREPARING AND HANDLINGï¿½TIME AND TEMPERATURE CONTROL FOR '
#                 'SAFETY(TCS)-(EGGS, BACON, SAUSAGE) FOODS WITHOUT ORIGINAL '
#                 'CITY OF CHICAGO FOOD SERVICE MANAGER AND CERTIFICATE ON SITE. '
#                 'INFORMED PERSON IN CHARGE CITY OF CHICAGO ORIGINAL FOOD '
#                 'SERVICE CERTIFICATE MUST REMAIN POSTED ON SITE AND CERTIFIED '
#                 'MANAGER ON SITE DURING TCS FOOD PREP, COOKING, SERVING AND '
#                 'OPERATING HOURS. PRIORITY FOUNDATION VIOLATION #7-38-012. '
#                 'CITATION ISSUED. (CERTIFIED FOODSERVICE MANAGER ARRIVED ON '
#                 'SITE DURING INSPECTION). | 55. PHYSICAL FACILITIES INSTALLED, '
#                 'MAINTAINED & CLEAN - Comments: OBSERVED SLIGHT BUILD UP OF '
#                 'RESIDUE UNDER SHELVING IN DRY STORAGE AREA. INSTRUCTED PERSON '
#                 'IN CHARGE TO CLEAN AND MAINTAIN.',
#   'zip': '60623'},
#  {':@computed_region_43wa_7qmu': '40',
#   ':@computed_region_6mkv_f3dw': '21190',
#   ':@computed_region_awaf_s7ux': '16',
#   ':@computed_region_bdys_3d7i': '649',
#   ':@computed_region_vrxf_vc4k': '46',
#   'address': '1970 W DIVERSEY PKWY ',
#   'aka_name': 'PIZZERIA UNO',
#   'city': 'CHICAGO',
#   'dba_name': 'PIZZERIA UNO',
#   'facility_type': 'Restaurant',
#   'inspection_date': '2022-12-14T00:00:00.000',
#   'inspection_id': '2568523',
#   'inspection_type': 'License',
#   'latitude': '41.93239810695521',
#   'license_': '2882448',
#   'location': {'latitude': '41.93239810695521',
#                'longitude': '-87.6778710361175',
#                'needs_recoding': False},
#   'longitude': '-87.6778710361175',
#   'results': 'Pass',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'violations': '36. THERMOMETERS PROVIDED & ACCURATE - Comments: THERMOMETERS '
#                 'IS NOT PROVIDED IN HOT HOLDING UNITS. COLD/HOT HOLDING '
#                 'EQUIPMENT USED FOR TIME/TEMPERATURE CONTROL FOR SAFETY SHALL '
#                 'HAVE AT LEAST ONE THERMOMETER IN AN EASILY VIEWED LOCATION. | '
#                 '53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & '
#                 'CLEANED - Comments: SINGLE EMPLOYEE RESTROOM LACKS A COVERED '
#                 'RECEPTACLE FOR DISPOSAL OF FEMININE HYGIENE PRODUCTS. PROVIDE '
#                 'AT LEAST ONE COVERED TRASH RECEPTACLE IN RESTROOM.',
#   'zip': '60614'},
#  {':@computed_region_43wa_7qmu': '2',
#   ':@computed_region_6mkv_f3dw': '21867',
#   ':@computed_region_awaf_s7ux': '44',
#   ':@computed_region_bdys_3d7i': '183',
#   ':@computed_region_vrxf_vc4k': '64',
#   'address': '6117 S KEDZIE AVE ',
#   'aka_name': 'SOUTHWEST SENIOR CENTER / GOLDEN DINER',
#   'city': 'CHICAGO',
#   'dba_name': 'SOUTHWEST SENIOR CENTER / GOLDEN DINER',
#   'facility_type': 'Golden Diner',
#   'inspection_date': '2022-12-14T00:00:00.000',
#   'inspection_id': '2568500',
#   'inspection_type': 'Canvass',
#   'latitude': '41.782098140853165',
#   'license_': '2224822',
#   'location': {'latitude': '41.782098140853165',
#                'longitude': '-87.70307836593555',
#                'needs_recoding': False},
#   'longitude': '-87.70307836593555',
#   'results': 'Pass',
#   'risk': 'Risk 1 (High)',
#   'state': 'IL',
#   'zip': '60629'}]
